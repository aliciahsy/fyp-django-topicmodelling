# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.corpus import stopwords
import nltk.tokenize as tk
from nltk.tokenize import word_tokenize
import string
from nltk.stem import PorterStemmer
stemmer = PorterStemmer
# Read the CSV file
df = pd.read_csv('C:\\Users\\Zude Ang\\VSC\\IND_TopicModellingOV\\Geopolitics.csv')

stop_words = stopwords.words('english')
new_stop = ['know','think','like','also','really','well','would','right','us','one','actually','people','city','year','question','yeah','going','lot','choose','feel'
            ,'perhaps','gon','say']
stop_words.extend(new_stop)
df['cleaned_corpus'] = ''

def cleaned_corpus(corpus):
    tokens = word_tokenize(corpus)

    tokens = [token.lower() for token in tokens if token.lower() not in stop_words]
    tokens = [token for token in tokens if not token.isnumeric()]
    tokens = [token for token in tokens if token not in string.punctuation]
    tokens = [token for token in tokens if token.isalnum()]
    # tokens = [stemmer.stem(token) for token in tokens]
    
    cleaned_corpus = ' '.join(tokens)
    return cleaned_corpus

df['cleaned_corpus'] = df['Text'].apply(cleaned_corpus)

# Initialize variables
segments = []
current_segment = {'Speaker': '', 'cleaned_corpus': ''}

# Iterate over the rows
for index, row in df.iterrows():
    # Get the segment value
    segment = row['Segment']
    
    # Check if it's a new segment
    if segment == 'Question':
        # Add the previous segment to the list
        if current_segment['cleaned_corpus']:
            segments.append(current_segment)
        
        # Start a new segment
        current_segment = {'Speaker': row['Speaker'], 'cleaned_corpus': row['cleaned_corpus']}
    else:
        # Append the text to the current segment
        current_segment['cleaned_corpus'] += ' ' + row['cleaned_corpus']

# Add the last segment to the list
if current_segment['cleaned_corpus']:
    segments.append(current_segment)

# Preprocess and vectorize the text
corpus = [segment['cleaned_corpus'] for segment in segments]
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)

# Apply LDA model
num_topics = 5  # Define the number of topics
lda = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda.fit(X)

# Get the topic distributions for each segment
segment_topics = lda.transform(X)

for i, segment in enumerate(segments):
    topic_dist = segment_topics[i]
    dominant_topic_idx = topic_dist.argmax()
    dominant_topic_prob = topic_dist[dominant_topic_idx]
    topic_words = lda.components_[dominant_topic_idx]
    top_words_idx = topic_words.argsort()[-5:]
    top_words = [vectorizer.get_feature_names_out()[idx] for idx in top_words_idx]
    
    print(f"Segment {i+1}:")
    print(f"Speaker: {segment['Speaker']}")
    print(f"Text: {segment['cleaned_corpus']}")
    print(f"Dominant Topic: {dominant_topic_idx}")
    print(f"Dominant Topic Probability: {dominant_topic_prob:.4f}")
    print(f"Top Words in Dominant Topic:")
    print(top_words)
    print()
# Out:
# Segment 1:
# Speaker:
# Text:  wtf series future future aims dive deep hot topics youth may scratching heads basically asked tough questions guys thank joining another episode wtf future future podcast series national youth councils asia ready exposure program partnership singapore institute international affairs today na unpacking something understand much thankfully experts um give topic global geopolitics define basically politics countries placed ah saw wikipedia research thing went wikipedia guessed yes pretty much broad sense breaking currently happening world terms global geopolitics covering bit china rivalry grew still happening yep episode na speak experts geopolitics obviously na discuss economic impacts region expect moving forward okay joining studio today got assistant professor ntu public policy global affairs dillon low channel news asia executive producer miss pearl force okay first obviously
# Dominant Topic: 4
# Dominant Topic Probability: 0.9201
# Top Words in Dominant Topic:
# ['global', 'young', 'superpower', 'asean', 'china']
#
# Segment 2:
# Speaker: 1
# ['global', 'young', 'superpower', 'asean', 'china']
#
# Segment 9:
# Speaker: 1
# Text: point want bring back dylan said asian politics sexy promote influence asean institutions singapore across asean needs sort curriculum introduced social studies textbooks primary secondary tertiary level least deals bit asean immediate neighbors affect multitude ways even equally important important china direct immediate neighbors institutionally level education done next public awareness podcast helpful regard way two minute two minute social media post speaks level hopefully connect use singapore use cliche leaders singapore future
# Dominant Topic: 0
# Dominant Topic Probability: 0.9017
# Top Words in Dominant Topic:
# ['neighbors', 'asean', 'back', 'level', 'china']
#
# Segment 10:
# Speaker: 1
# Text: oh tough get use technology video maximum three five minutes minutes okay minutes said politics sexy mean fantastic see young engaged expensive traveling way europe certainly suffer long flight take advantage culture vibrancy beauty around maybe aside curriculum simply backpacking around region love see advice youth want discover asean travel go figure sure traveling talking maybe might immediately interested politics getting sense economic growth culture good segue understanding politics region interesting get honestly never backpacking asia oh stopped first trip never ever forget always wanted backpack mom alone wanted go south thailand go lao go hanoi way ho chi minh found exactly said super interesting discover things normally discover super super fun good opportunity bring back aep absolutely everybody backpacking sort example asia ready exposure program something allows youth meaningful exposure asean states gives chance short term program gives cultural exposure get industry experience places china india get opportunities beyond singapore heard meet industry speak youth something definitely eye opening growing opportunity definitely jump opportunity travel opportunity see asean experience firsthand different
# Dominant Topic: 1
# Dominant Topic Probability: 0.9260
# Top Words in Dominant Topic:
# ['super', 'opportunity', 'asia', 'southeast', 'asean']
#
# Segment 11:
# Speaker: 1
# Text: talked affects youth singapore world globally geopolitical situation affect global situation let tell group young interviewed shows china tensions became bad went states spoke china students studying chinese students form greatest number foreign students pandemic different universities paying full fees okay geopolitical situation got worst problems visa renewals students research day welcomed welcome day seen spies saboteurs bad quite difficult china youth choosing study looking places pursue university studies research programs pity geopolitics bad relations better definitely dynamism young china put together create amazing scientific breakthroughs interesting products real problem mean situations got singaporeans working china could leave many years could see family many years policies instituted mean spoken course thing studies research china known learn okay let tell fun thing talking serious things young exchange programs love applying university president xi young exchange program part went iowa already civil servant went iowa learn farming part trip stayed american citizens home name sarah lundy spoke interview incident time stayed bedroom teenage son away college room full star wars interestingly became vice president went back visit family iowa house muscatine iowa since turned china friendship house sarah landay lady hosted wrote wrote back carried chinese media oh sitting beings daughter studied harvard come back became president share factoid small factoid less americans passport less chinese passports tells several things amount happening outside china definitely amount china knows happening outside china great second means potential scope sorts exchanges exchanges hopefully hopefully foster greater mutual understanding level china
# Dominant Topic: 4
# Dominant Topic Probability: 0.9366
# Top Words in Dominant Topic:
# ['global', 'young', 'superpower', 'asean', 'china']
#
# Segment 12:
# Speaker: 1
# Text: domestically may travel even need passport next cash card absolutely youth globally could afford travel learn world learn cultural historical historical significance avery backpacking asia okay end let let try something guys piece advice youth geopolitics easiest piece advice day age youth please rely facebook news important um echo chamber toread white sauce time read everyone least read local news media depend social circles news information watch prostarch absolutely echo chamber dangerous moving forward unlike pearl spend bit time reading things always questioning questioning source questioning said um come conclusions questioning read basically fact check mean surprising media coming conversation today looking intentions media sources important advice travel um see world pulse na get younger age want step comfort zones take big leap faith na go travel na go discover culture realize wow amazing learn everything firsthand mine exciting missed missed exit highway got stuck mexico without passport got detained tijuana yes experience
# Dominant Topic: 3
# Dominant Topic Probability: 0.9238
# Top Words in Dominant Topic:
# ['questioning', 'everyone', 'world', 'china', 'war']
